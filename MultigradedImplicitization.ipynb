# %%
using Pkg
Pkg.add("Oscar")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed Antic_jll ────────────────── v0.201.500+0
#    Installed MongoC_jll ───────────────── v1.19.1+0
#    Installed GR_jll ───────────────────── v0.72.10+0
#    Installed LRUCache ─────────────────── v1.5.0
#    Installed HypergeometricFunctions ──── v0.3.23
#    Installed OffsetArrays ─────────────── v1.12.10
#    Installed MutableArithmetics ───────── v1.3.3
#    Installed Preferences ──────────────── v1.4.1
#    Installed Perl_jll ─────────────────── v5.34.0+2
#    Installed FLINT_jll ────────────────── v200.900.7+0
#    Installed LoggingExtras ────────────── v1.0.3
#    Installed Xorg_xkbcomp_jll ─────────── v1.4.6+0
#    Installed Permutations ─────────────── v0.4.17
#    Installed DomainSets ───────────────── v0.6.7
#    Installed AlgebraicSolving ─────────── v0.3.3
#    Installed RelocatableFolders ───────── v1.0.1
#    Installed PDMats ───────────────────── v0.11.26
# ...
